# %%
import pymongo
import hashlib
import csv
import prettytable
import requests 
import json

# %%
from pymongo import MongoClient, errors

# %%
client = pymongo.MongoClient("mongodb://Jakester:Google%24%24nexus5@cluster0-shard-00-00-l6asu.mongodb.net:27017,cluster0-shard-00-01-l6asu.mongodb.net:27017,cluster0-shard-00-02-l6asu.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
url = ("https://services.arcgis.com/S9th0jAJ7bqgIRjw/arcgis/rest/services/MCI_2014_to_2019/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")
json = requests.get(url).json()

# %%
db = client.test
collection = db.sachin_collection

# %%
collection.insert_many(json['features'])

# %%
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('5e628e972adf8060ec4fcb0d'), 'attributes': {'Index_': 101, 'event_unique_id': 'GO-20141670830', 'occurrencedate': 1393516800000, 'reporteddate': 1394388840000, 'premisetype': 'House', 'ucr_code': 2132, 'ucr_ext': 200, 'offence': 'Theft From Motor Vehicle Over', 'reportedyear': 2014, 'reportedmonth': 'March', 'reportedday': 9, 'reporteddayofyear': 68, 'reporteddayofweek': 'Sunday    ', 'reportedhour': 18, 'occurrenceyear': 2014, 'occurrencemonth': 'February', 'occurrenceday': 27, 'occurrencedayofyear': 58, 'occurrencedayofweek': 'Thursday  ', 'occurrencehour': 16, 'MCI': 'Theft Over', 'Division': 'D53', 'Hood_ID': 101, 'Neighbourhood': 'Forest Hill South (101)', 'Long': -79.4176865, 'Lat': 43.7005615, 'ObjectId': 1}, 'geometry': {'x': -79.4176865, 'y': 43.7005615}}
# ...
